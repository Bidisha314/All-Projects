# %% [markdown]
# <a href="https://colab.research.google.com/github/Bidisha314/All-Projects/blob/main/FaceSwap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Create Your Own Face Swap Application:**
#
# *   Run Time: CPU
# *   GitHub Link: https://github.com/TheMasterFX/face-swap-ui
# *   Self-hosting Tool: https://pinggy.io/
# *   Run Local host:`http://127.0.0.1:7860`

# %% [markdown]
# # Step 1: Git clone face-swap-ui

# %%
# %cd /content
# !rm -rf face-swap-ui
# !git clone https://github.com/TheMasterFX/face-swap-ui.git
# Out:
# /content
# Cloning into 'face-swap-ui'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 23 (delta 7), reused 19 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 19.39 KiB | 4.85 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %% [markdown]
# # Step 2: Download Face Swap Model

# %%
# !mkdir -p /root/.insightface/models
# !wget -O /root/.insightface/models/inswapper_128.onnx \
https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx
# Out:
# --2026-01-13 07:02:46--  https://huggingface.co/ezioruan/inswapper_128.onnx/resolve/main/inswapper_128.onnx
# Resolving huggingface.co (huggingface.co)... 3.170.185.35, 3.170.185.25, 3.170.185.14, ...
# Connecting to huggingface.co (huggingface.co)|3.170.185.35|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# # Step 3: Install requirements

# %%
# %cd /content/face-swap-ui
# !pip install --upgrade pip
# !pip install -r requirements.txt
# Out:
# /content/face-swap-ui
# ...

# %% [markdown]
# # Step 4: Quick Patch Fix

# %%
# !sed -i "s|get_model('inswapper_128.onnx'.*|get_model('/root/.insightface/models/inswapper_128.onnx', download=False)|" face_swap_ui.py

# %%
# !sed -i "s/Label=/label=/g" face_swap_ui.py

# %%
# !sed -i "s/\.style(height=400)//g" face_swap_ui.py

# %% [markdown]
# # Step 5: Set Up Pinggy Tunnel

# %% [markdown]
# ### Install Pinggy:

# %%
# !pip install pinggy

# %% [markdown]
# ### Create Pinggy Tunnel:

# %%
import pinggy

tunnel = pinggy.start_tunnel(forwardto="localhost:7860")
print("Public URLs:", tunnel.urls)
# Out:
# Public URLs: ['http://kubqd-136-113-122-149.a.free.pinggy.link', 'https://kubqd-136-113-122-149.a.free.pinggy.link']

# %% [markdown]
# # Step 6: Run the Face Swap UI

# %%
# !python face_swap_ui.py
# Out:
# /usr/local/lib/python3.12/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:123: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: /root/.insightface/models/buffalo_l/det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# ...
